# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Loading the Data & EDA

# %%
import pandas as pd

df = pd.read_csv("Train_data.csv")
df.head()
# Out:
#    duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0         0           tcp  ftp_data   SF        491          0     0
# 1         0           udp     other   SF        146          0     0
# 2         0           tcp   private   S0          0          0     0
# 3         0           tcp      http   SF        232       8153     0
# 4         0           tcp      http   SF        199        420     0
#
#    wrong_fragment  urgent  hot  ...  dst_host_srv_count  \
# 0               0       0    0  ...                  25
# 1               0       0    0  ...                   1
# 2               0       0    0  ...                  26
# 3               0       0    0  ...                 255
# 4               0       0    0  ...                 255
#
#    dst_host_same_srv_rate  dst_host_diff_srv_rate  \
# 0                    0.17                    0.03
# 1                    0.00                    0.60
# 2                    0.10                    0.05
# ...

# %%
df.describe()
# Out:
#            duration     src_bytes     dst_bytes          land  wrong_fragment  \
# count  25192.000000  2.519200e+04  2.519200e+04  25192.000000    25192.000000
# mean     305.054104  2.433063e+04  3.491847e+03      0.000079        0.023738
# std     2686.555640  2.410805e+06  8.883072e+04      0.008910        0.260221
# min        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 25%        0.000000  0.000000e+00  0.000000e+00      0.000000        0.000000
# 50%        0.000000  4.400000e+01  0.000000e+00      0.000000        0.000000
# 75%        0.000000  2.790000e+02  5.302500e+02      0.000000        0.000000
# max    42862.000000  3.817091e+08  5.151385e+06      1.000000        3.000000
#
#             urgent           hot  num_failed_logins     logged_in  \
# count  25192.00000  25192.000000       25192.000000  25192.000000
# mean       0.00004      0.198039           0.001191      0.394768
# std        0.00630      2.154202           0.045418      0.488811
# ...

# %%
df["class"].value_counts()
# Out:
# class
# normal     13449
# anomaly    11743
# Name: count, dtype: int64

# %%
df.nunique()
# Out:
# duration                        758
# protocol_type                     3
# service                          66
# flag                             11
# src_bytes                      1665
# dst_bytes                      3922
# land                              2
# wrong_fragment                    3
# urgent                            2
# hot                              22
# num_failed_logins                 5
# logged_in                         2
# num_compromised                  28
# root_shell                        2
# su_attempted                      3
# num_root                         28
# num_file_creations               20
# num_shells                        2
# num_access_files                  7
# num_outbound_cmds                 1
# is_host_login                     1
# is_guest_login                    2
# count                           466
# srv_count                       414
# serror_rate                      70
# srv_serror_rate                  56
# ...

# %% [markdown]
# # Step Regression

# %% [markdown]
# ## Splitting & Encoding Data

# %%
# train_df = df.sample(n=5000, random_state=42)
train_df = df.sample(frac=0.8, random_state=42)
test_df = df.drop(train_df.index)

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
X_train = train_df.drop('class', axis=1)
y_train = le.fit_transform(train_df['class'])

X_test = test_df.drop('class', axis=1)
y_test = le.transform(test_df['class'])

# %% [markdown]
# ## Create Sklearn Pipeline with BIC metric.

# %%
import numpy as np
from sklearn.metrics import make_scorer

def bic_scorer(y, y_pred, **kwargs):
   n_samples = len(y)
   residual_sum_squares = np.sum((y - y_pred) ** 2)
   n_features = kwargs.get('n_features')
   bic = n_samples * np.log(residual_sum_squares/n_samples) + n_features * np.log(n_samples)
   return -bic

custom_scorer = make_scorer(bic_scorer, n_features=X_train.shape[1])

# %%
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Split features by type
categorical_features = ['protocol_type', 'service', 'flag']
numeric_features = [col for col in df.columns if col not in categorical_features + ['class']]

preprocessor = ColumnTransformer([
    ('num', StandardScaler(), numeric_features),
    ('cat', OneHotEncoder(drop='first'), categorical_features)
])

sfs = SequentialFeatureSelector(
    LogisticRegression(),
    n_features_to_select='auto',
    direction='forward',  # or 'backward' or 'bidirectional'
    cv=5,
    scoring=custom_scorer,
    n_jobs=-1,
)

classifier = LogisticRegression()

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('feature_selection', sfs),
    ('regressor', classifier)
])

# %% [markdown]
# ## Fit the model
#
# This uses the BIC metric to select the best features and then fits a Logistic Regression model with those features.

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['duration', 'src_bytes',
#                                                    'dst_bytes', 'land',
#                                                    'wrong_fragment', 'urgent',
#                                                    'hot', 'num_failed_logins',
#                                                    'logged_in',
#                                                    'num_compromised',
#                                                    'root_shell', 'su_attempted',
#                                                    'num_root',
#                                                    'num_file_creations',
#                                                    'num_shells',
#                                                    'num_access_files',
# ...

# %%
# Get the number of selected features

feature_mask = pipeline.named_steps['feature_selection'].get_support()
len(feature_mask)
# Out:
# 115

# %%
preprocessor = pipeline.named_steps['preprocessor']
transformed_features = (
    numeric_features + 
    preprocessor.named_transformers_['cat'].get_feature_names_out(categorical_features).tolist()
)

# Get selected features
feature_mask = pipeline.named_steps['feature_selection'].get_support()
selected_features = [f for f, selected in zip(transformed_features, feature_mask) if selected]

# %%
selected_features
# Out:
# ['dst_bytes',
#  'urgent',
#  'logged_in',
#  'num_compromised',
#  'num_file_creations',
#  'num_shells',
#  'num_access_files',
#  'num_outbound_cmds',
#  'is_host_login',
#  'diff_srv_rate',
#  'dst_host_same_srv_rate',
#  'service_X11',
#  'service_auth',
#  'service_bgp',
#  'service_courier',
#  'service_csnet_ns',
#  'service_ctf',
#  'service_discard',
#  'service_echo',
#  'service_eco_i',
#  'service_ecr_i',
#  'service_efs',
#  'service_exec',
#  'service_finger',
#  'service_ftp_data',
#  'service_hostnames',
#  'service_http',
#  'service_http_8001',
#  'service_imap4',
#  'service_kshell',
#  'service_ldap',
#  'service_login',
#  'service_mtp',
#  'service_netbios_ssn',
#  'service_nntp',
#  'service_other',
#  'service_pop_2',
#  'service_pop_3',
#  'service_printer',
#  'service_private',
#  'service_remote_job',
#  'service_rje',
#  'service_shell',
#  'service_smtp',
#  'service_ssh',
#  'service_supdup',
#  'service_urh_i',
#  'service_urp_i',
#  'service_uucp',
# ...

# %%
len(selected_features)
# Out:
# 57

# %%
len([f for f in selected_features if f.startswith('service_')])
# Out:
# 39

# %%
y_pred = pipeline.predict(X_test)

# Model metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# Get feature importance scores from final logistic regression
feature_importance = pd.DataFrame({
   'feature': selected_features,
   'importance': abs(pipeline.named_steps['regressor'].coef_[0])
}).sort_values('importance', ascending=False)
# Out:
# [[2233  100]
#  [  69 2636]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      2333
#            1       0.96      0.97      0.97      2705
#
#     accuracy                           0.97      5038
#    macro avg       0.97      0.97      0.97      5038
# weighted avg       0.97      0.97      0.97      5038

# %%
feature_importance
# Out:
#                    feature  importance
# 20           service_ecr_i    6.145302
# 19           service_eco_i    6.058247
# 52                 flag_S1    5.527404
# 55                 flag_SF    5.341241
# 39         service_private    3.740892
# 54                 flag_S3    3.668847
# 28           service_imap4    2.701362
# 43            service_smtp    2.562680
# 53                 flag_S2    2.291747
# 26            service_http    2.124266
# 11             service_X11    2.113798
# 48            service_uucp    1.624803
# 47           service_urp_i    1.456649
# 37           service_pop_3    1.413748
# 50               flag_RSTO    1.295456
# 14         service_courier    1.217532
# 49           service_whois    1.182326
# 13             service_bgp    1.175087
# 22            service_exec    1.170515
# 17         service_discard    1.135226
# 33     service_netbios_ssn    1.110232
# 16             service_ctf    1.101369
# 34            service_nntp    1.097217
# ...

# %% [markdown]
# # Save and Load the Model/Pipeline

# %%
import pickle

# save
with open('pipeline.pkl','wb') as f:
    pickle.dump(pipeline,f)

# %%
import pickle

# load
with open('pipeline.pkl', 'rb') as f:
    pipeline2 = pickle.load(f)
